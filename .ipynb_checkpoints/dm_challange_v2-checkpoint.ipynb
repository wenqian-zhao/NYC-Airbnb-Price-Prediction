# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import FunctionTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error as mse
from sklearn.ensemble import *
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
from sklearn.decomposition import PCA
from scipy.stats import mode
from sklearn.impute import SimpleImputer
from fun import *

# %%
airbnb = pd.read_csv("data/train.csv")
# Out:
# c:\users\zhaow\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3169: DtypeWarning: Columns (30) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
sns.distplot(airbnb[airbnb["interaction"].isnull()].price)
sns.distplot(airbnb[airbnb["interaction"].notnull()].price)
# Out:
# C:\Users\zhaow\AppData\Roaming\Python\Python39\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\zhaow\AppData\Roaming\Python\Python39\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
sns.distplot(airbnb[airbnb["host_neighbourhood"]=="Williamsburg"].price)
sns.distplot(airbnb[airbnb["host_neighbourhood"] == "Bedford-Stuyvesant"].price)
# Out:
# C:\Users\zhaow\AppData\Roaming\Python\Python39\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\zhaow\AppData\Roaming\Python\Python39\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
grouped_veri = airbnb[["host_verifications", "price"]]
grouped_veri["host_verifications"] = grouped_veri["host_verifications"].apply(lambda x: x.count(",")+1 if len(x)>4 else 0)
grouped_veri = grouped_veri.groupby("host_verifications")["price"].mean()
grouped_veri
# Out:
# C:\Users\zhaow\AppData\Local\Temp/ipykernel_8492/3869303792.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grouped_veri["host_verifications"] = grouped_veri["host_verifications"].apply(lambda x: x.count(",")+1 if len(x)>4 else 0)
# host_verifications
# 0     131.071429
# 1     144.682390
# 2     155.266805
# 3     139.205459
# 4     141.387009
# 5     145.927369
# 6     144.856243
# 7     146.184154
# 8     149.979359
# 9     141.554726
# 10    139.390029
# 11    173.453125
# 12    171.416667
# Name: price, dtype: float64

# %%
sns.scatterplot(x=airbnb.host_id, y=airbnb.price)
# Out:
# <AxesSubplot:xlabel='host_id', ylabel='price'>

# %%
airbnb["host_verifications"].apply(len).value_counts().sort_index()
# Out:
# 2       37
# 4        5
# 9      631
# 11       2
# 12       3
#       ...
# 156      3
# 158      3
# 163      2
# 167      1
# 170      2
# Name: host_verifications, Length: 136, dtype: int64

# %%
airbnb[airbnb["host_verifications"].apply(len)==4].host_verifications
# Out:
# 10782    None
# 14341    None
# 19041    None
# 30709    None
# 32088    None
# Name: host_verifications, dtype: object

# %%
test = pd.read_csv("data/test.csv")

# %%
entire = pd.read_csv("data/AB_NYC_2019.csv")

# %%
res = [1,2,3]
list(map(lambda x: x**2, res))
# Out:
# [1, 4, 9]

# %%
test.head()
# Out:
#          id                                              name  \
# 0  19307997               Super Lux 2BR in Downtown Manhattan
# 1  20176193       Vintage Eclectic Brownstone Pad in Brooklyn
# 2  19485371                          Spacious Harlem Hideaway
# 3  13079990                  Spacius private room in Brooklyn
# 4  22339757  *Dg) Delightful Private Room 20 min to Manhattan
#
#                                              summary  \
# 0  Prepare to be WOWED! This spectacularly bright...
# 1  Ideal for romantic, creative types, this is an...
# 2  Postive Vibes . This is our Harlem tree house,...
# 3  Newly renovated apartment, its a 3 bedroom apa...
# 4  Hi my home is only 2 blocks from the subway st...
#
#                                                space  \
# 0  Top of the line Wolf and Sub-Zero appliances, ...
# 1  Not your typical New York abode, my apartment ...
# 2  The private room is very spacious and cozy. Th...
# 3  3 bedroom apartment, 1 full bathroom, living r...
# 4                                                NaN
#
#                                          description experiences_offered  \
# 0  Prepare to be WOWED! This spectacularly bright...                none
# 1  Ideal for romantic, creative types, this is an...                none
# 2  Postive Vibes . This is our Harlem tree house,...                none
# 3  Newly renovated apartment, its a 3 bedroom apa...                none
# 4  Hi my home is only 2 blocks from the subway st...                none
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1  Bed Stuy is a diverse historic neighborhood wi...
# 2  You are in a Cultural Haven full of restaurant...
# 3                                                NaN
# 4                                                NaN
#
#                                                notes  \
# 0                                                NaN
# 1  This is an actual unique living experience whe...
# 2  We also keep cucumber water in the fridge feel...
# 3                                                NaN
# 4                                                NaN
#
#                                              transit  \
# 0                                                NaN
# 1  Close to buses and subways there is also free ...
# 2  Train, uber or a taxi. (Extremely taxi accessi...
# 3  There is the Mta 3 train Sutter stop, also the...
# 4                                                NaN
#
#                                               access  ...  \
# 0                                                NaN  ...
# 1  Entrance hallway, living room, bedroom, kitche...  ...
# 2                 Private Room, Kitchen And Bathroom  ...
# 3                                                NaN  ...
# 4                                                NaN  ...
#
#   review_scores_communication review_scores_location  review_scores_value  \
# 0                         NaN                    NaN                  NaN
# 1                        10.0                   10.0                 10.0
# 2                        10.0                   10.0                 10.0
# 3                         9.0                    8.0                  9.0
# 4                         8.0                    8.0                  8.0
#
#   instant_bookable is_business_travel_ready          cancellation_policy  \
# 0                f                        f                     flexible
# 1                f                        f                     flexible
# 2                t                        f                     flexible
# 3                f                        f                     flexible
# 4                t                        f  strict_14_with_grace_period
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
# 2                             f                                f
# 3                             f                                f
# 4                             f                                f
#
#   calculated_host_listings_count  reviews_per_month
# 0                              1                NaN
# 1                              1               1.48
# 2                              1               0.37
# 3                              1               0.23
# 4                              9               1.53
#
# [5 rows x 64 columns]

# %%
overlap = pd.merge(left = test, right = entire[["id", "price"]], on = "id", how = "inner")

# %%
overlap
# Out:
#              id                                               name  \
# 0      19307997                Super Lux 2BR in Downtown Manhattan
# 1      19485371                           Spacious Harlem Hideaway
# 2      22339757   *Dg) Delightful Private Room 20 min to Manhattan
# 3      19416433                 Stylish Studio in the heart of NYC
# 4       3167768                    Family-friendly 3-bedroom condo
# ...         ...                                                ...
# 11628  20898641                                  Cabin in Bushwick
# 11629  22325617                          Charming room in Brooklyn
# 11630   8372650                     Luxurious 1BR in Herald Square
# 11631   3812554                Master Bedrm, Steam Shr/Jacuzzi, FH
# 11632  18891508  Private rooms starting at $67 a night per person.
#
#                                                  summary  \
# 0      Prepare to be WOWED! This spectacularly bright...
# 1      Postive Vibes . This is our Harlem tree house,...
# 2      Hi my home is only 2 blocks from the subway st...
# 3      Japanese style, paintings, sculptors, a lot li...
# 4      Our large, light-filled home sleeps 6 comforta...
# ...                                                  ...
# 11628  This haven in Bushwick is a cozy and comfortab...
# 11629  Charming newly renovated 2 bed apartment in Be...
# 11630  -Apartment includes: Hardwood Floors, High Cei...
# 11631  Elegant room w/AC, King Bed, Jacuzzi and Steam...
# 11632  Family friendly neighborhood. Caribbean settin...
#
#                                                    space  \
# 0      Top of the line Wolf and Sub-Zero appliances, ...
# 1      The private room is very spacious and cozy. Th...
# 2                                                    NaN
# 3                              Very quiet and very clean
# 4      Our 4th-floor apartment is light-filled, spaci...
# ...                                                  ...
# 11628  Just a 5 minute walk to the L & M trains and w...
# 11629                                                NaN
# 11630  - ONE proper bed that can sleep 2. - ONE plush...
# 11631  This stately red brick federal on a quiet stre...
# 11632  You have a choice of 1 of 4 bedrooms. Room#4 c...
#
#                                              description experiences_offered  \
# 0      Prepare to be WOWED! This spectacularly bright...                none
# 1      Postive Vibes . This is our Harlem tree house,...                none
# 2      Hi my home is only 2 blocks from the subway st...                none
# 3      Japanese style, paintings, sculptors, a lot li...                none
# 4      Our large, light-filled home sleeps 6 comforta...                none
# ...                                                  ...                 ...
# 11628  This haven in Bushwick is a cozy and comfortab...                none
# 11629  Charming newly renovated 2 bed apartment in Be...                none
# 11630  -Apartment includes: Hardwood Floors, High Cei...                none
# 11631  Elegant room w/AC, King Bed, Jacuzzi and Steam...                none
# 11632  Family friendly neighborhood. Caribbean settin...                none
#
#                                    neighborhood_overview  \
# 0                                                    NaN
# 1      You are in a Cultural Haven full of restaurant...
# 2                                                    NaN
# 3      It is a great neighborhood!!!: a lot restauran...
# 4      Our neighborhood is AWESOME! When we moved her...
# ...                                                  ...
# 11628  Immediate neighborhood is quiet, safe and frie...
# 11629                                                NaN
# 11630  Smack in the middle of Manhattan. Near the Emp...
# 11631  It's easy to enjoy all that NYC has to offer f...
# 11632  The neighborhood has easy access to Manhattan....
#
#                                                    notes  \
# 0                                                    NaN
# 1      We also keep cucumber water in the fridge feel...
# 2                                                    NaN
# 3      I am strictly vegetarian. I expect that the gu...
# 4      -Security deposit required -Once-a-week cleani...
# ...                                                  ...
# 11628                                                NaN
# 11629                                                NaN
# 11630                                                NaN
# 11631  Guests are expected to respect others' needs f...
# 11632  Our place can also be available for $249 a nig...
#
#                                                  transit  \
# 0                                                    NaN
# 1      Train, uber or a taxi. (Extremely taxi accessi...
# 2                                                    NaN
# 3      A lot subways: A, C, 1, N, R, Q, B, D, F, M Th...
# 4      Subways: 10 minute walk to 2/3/B/Q/C trains; b...
# ...                                                  ...
# 11628  Easy walk to local spots, two subway train lin...
# 11629  Though street parking is available, space is 2...
# 11630                                                NaN
# 11631  A three block walk to the Forest Hills/71st Rd...
# 11632  Buses are 1 block away. A 10 minute ride in th...
#
#                                                   access  ...  \
# 0                                                    NaN  ...
# 1                     Private Room, Kitchen And Bathroom  ...
# 2                                                    NaN  ...
# 3                                                    NaN  ...
# 4      Make yourselves at home! Space provided in a n...  ...
# ...                                                  ...  ...
# 11628  Feel free to enjoy the front courtyard (beach ...  ...
# 11629                                                NaN  ...
# 11630                                                NaN  ...
# 11631  Guests have access to the common areas of the ...  ...
# 11632  Coffee, tea, cocoa and various juices are prov...  ...
#
#       review_scores_location review_scores_value  instant_bookable  \
# 0                        NaN                 NaN                 f
# 1                       10.0                10.0                 t
# 2                        8.0                 8.0                 t
# 3                        NaN                 NaN                 f
# 4                        9.0                10.0                 f
# ...                      ...                 ...               ...
# 11628                    9.0                10.0                 f
# 11629                    NaN                 NaN                 t
# 11630                    NaN                 NaN                 f
# 11631                   10.0                10.0                 f
# 11632                    9.0                10.0                 f
#
#       is_business_travel_ready          cancellation_policy  \
# 0                            f                     flexible
# 1                            f                     flexible
# 2                            f  strict_14_with_grace_period
# 3                            f                     flexible
# 4                            f  strict_14_with_grace_period
# ...                        ...                          ...
# 11628                        f                     flexible
# 11629                        f                     flexible
# 11630                        f  strict_14_with_grace_period
# 11631                        f                     moderate
# 11632                        f                     moderate
#
#       require_guest_profile_picture require_guest_phone_verification  \
# 0                                 f                                f
# 1                                 f                                f
# 2                                 f                                f
# 3                                 f                                f
# 4                                 f                                f
# ...                             ...                              ...
# 11628                             f                                f
# 11629                             f                                f
# 11630                             f                                f
# 11631                             f                                f
# 11632                             f                                f
#
#       calculated_host_listings_count reviews_per_month  price
# 0                                  1               NaN    390
# 1                                  1              0.37     65
# 2                                  9              1.53     67
# 3                                  1              0.19    132
# 4                                  1              0.33    275
# ...                              ...               ...    ...
# 11628                              1              0.78    102
# 11629                              1               NaN     40
# 11630                              1               NaN    300
# 11631                              3              1.32    145
# 11632                              4              0.29     67
#
# [11633 rows x 65 columns]

# %%
pred = pd.read_csv("output/prediction.csv")
merge_pred = pred.merge(overlap, on = "id")
(((merge_pred.price - merge_pred.Predicted)**2).mean())**0.5
# Out:
# 80.50992656602241

# %%
# Out:
# 81.16488077362654

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x=merge_pred.Predicted, y=merge_pred.price)
plt.plot([0, 2000], [0, 2000], marker = "o", zorder = 3, color="red")

# %%
overlap[overlap["price"] > 1300]
# Out:
#              id                                               name  \
# 154     2284454                   MANHATTAN SUPERBOWL ACCOMODATION
# 956    20016493          ART LOFT/HOME: DINNERS, GATHERINGS, PHOTO
# 2811   29486682                 Loft Space with Incredible Windows
# 3953    2250372                  Huge 3BR Penthouse, Private Roof!
# 5594    2186452                    Tribeca Loft for Superbowl Wknd
# 5886    2276065                             PERFECT SUPERBOWL STAY
# 7403    2261367                brooklyn 14 bedroom gated community
# 8574    2250170                Spacious/New 3 Bedroom East Village
# 9366    1301321                West Village Penthouse-terrace/view
# 9784    6702693     Clean modern 4BR/4.5Bath 6,000sf Loft Union Sq
# 9958    5131879                  Large, comfy 1br in Williamsburg!
# 10057   1989838                 Luxury 4 BD NYC Times Sq Apartment
# 11142  24983084  Triple Mint Townhouse in the heart of West Vil...
# 11368   7380251                 Private Room in New Bed-Stuy Lofts
#
#                                                  summary  \
# 154    We have 2 apartments available in the Upper Ea...
# 956    This Noho Art Loft is fantastic for gatherings...
# 2811   Amazing Loft space in the middle of it all, ov...
# 3953   Situated at the top of a brownstone townhouse ...
# 5594   Large Tribeca Loft available for Superbowl wee...
# 5886   Located at 36th and 6th avenue in midtown, hal...
# 7403   One of a kind in Brooklyn! A huge home it incl...
# 8574   2 blocks from main subway line 10minute walk -...
# 9366   Penthouse with private terrace and amazing vie...
# 9784   This super clean, sunny, contemporary 6000sf l...
# 9958                                                 NaN
# 10057  Superb location just blocks away from Times Sq...
# 11142  Beautiful townhouse with private garden and ro...
# 11368  Private bedroom available in a 2 bedroom/ 1 ba...
#
#                                                    space  \
# 154    Ideal for a group coming to town for the super...
# 956    This Art loft is part of the Original Empire S...
# 2811                                                 NaN
# 3953   We are proud to present a gorgeous 2,900 squar...
# 5594                                                 NaN
# 5886   Beautiful, spacious & clean 1 bedroom in the m...
# 7403   Our building is a legal hotel each room as a h...
# 8574                                                 NaN
# 9366   Private wraparound terrace on the top floor of...
# 9784   This space is quiet with CityQuiet double wind...
# 9958   650 sq. ft., kitchen, livingroom w/ dining are...
# 10057  Huge space for NYC! Perfectly located and supe...
# 11142                                                NaN
# 11368                                                NaN
#
#                                              description experiences_offered  \
# 154    We have 2 apartments available in the Upper Ea...                none
# 956    This Noho Art Loft is fantastic for gatherings...                none
# 2811   Amazing Loft space in the middle of it all, ov...                none
# 3953   Situated at the top of a brownstone townhouse ...                none
# 5594   Large Tribeca Loft available for Superbowl wee...                none
# 5886   Located at 36th and 6th avenue in midtown, hal...                none
# 7403   One of a kind in Brooklyn! A huge home it incl...                none
# 8574   2 blocks from main subway line 10minute walk -...                none
# 9366   Penthouse with private terrace and amazing vie...                none
# 9784   This super clean, sunny, contemporary (Phone n...                none
# 9958   650 sq. ft., kitchen, livingroom w/ dining are...                none
# 10057  Superb location just blocks away from Times Sq...                none
# 11142  Beautiful townhouse with private garden and ro...                none
# 11368  Private bedroom available in a 2 bedroom/ 1 ba...                none
#
#                                    neighborhood_overview  \
# 154    Upper East Side is a super safe area, packed w...
# 956    Prime location steps from the best shops, rest...
# 2811                                                 NaN
# 3953   The apartment is centrally located in Kips Bay...
# 5594                                                 NaN
# 5886                                    Near EVERYTHING.
# 7403   Sea Gate is a hidden gem. In the summer the oc...
# 8574                                                 NaN
# 9366                                                 NaN
# 9784   At the end of the block is a major subway hub,...
# 9958   Great area--very safe, lots to do! Surrounded ...
# 10057  Laundry and Dry Cleaning around the corner Cen...
# 11142                                                NaN
# 11368                                                NaN
#
#                                                    notes  \
# 154                                                  NaN
# 956    Pricing will vary depending on purpose of the ...
# 2811                                                 NaN
# 3953   Please contact me with any questions you may h...
# 5594                                                 NaN
# 5886                                                 NaN
# 7403                                                 NaN
# 8574                                                 NaN
# 9366                                                 NaN
# 9784   Full size laundry room with additional large f...
# 9958                                                 NaN
# 10057                                                NaN
# 11142                                                NaN
# 11368                                                NaN
#
#                                                  transit  \
# 154    The apartments are a ten minute walk from the ...
# 956    This loft is conveniently located only one blo...
# 2811                                                 NaN
# 3953   The subway-proximate location makes getting ar...
# 5594                                                 NaN
# 5886   1,2,3,N,R,Q,B,D,F,N trains less than a block a...
# 7403   Public transportation is available outside the...
# 8574                                                 NaN
# 9366                                                 NaN
# 9784   The 4,5,6 trains are at the end of the block (...
# 9958   Right off Lorimer L/Metropolitan G. About a 4 ...
# 10057  Local metro stations: 57&7: NQR, 7th Avenue: B...
# 11142                                                NaN
# 11368                                                NaN
#
#                                                   access  ...  \
# 154    One double bed, one king size bed, 2 double so...  ...
# 956        Guests have access to all parts of the space.  ...
# 2811                                                 NaN  ...
# 3953   Lower Level (1st Floor) •Master bedroom featur...  ...
# 5594                                                 NaN  ...
# 5886                                          Roof deck.  ...
# 7403   Small or big kitchen to be discussed. The full...  ...
# 8574                                                 NaN  ...
# 9366                                                 NaN  ...
# 9784   We will greet you to give you keys, show you t...  ...
# 9958                                                 NaN  ...
# 10057      Living room, kitchen, bathrooms and bedrooms.  ...
# 11142                                                NaN  ...
# 11368                                                NaN  ...
#
#       review_scores_location review_scores_value  instant_bookable  \
# 154                      NaN                 NaN                 f
# 956                     10.0                10.0                 f
# 2811                     NaN                 NaN                 t
# 3953                     NaN                 NaN                 f
# 5594                     NaN                 NaN                 f
# 5886                     NaN                 NaN                 f
# 7403                    10.0                10.0                 t
# 8574                     NaN                 NaN                 f
# 9366                    10.0                 9.0                 f
# 9784                    10.0                 9.0                 t
# 9958                     NaN                 NaN                 f
# 10057                    NaN                 NaN                 f
# 11142                   10.0                 9.0                 f
# 11368                    NaN                 NaN                 f
#
#       is_business_travel_ready          cancellation_policy  \
# 154                          f                     flexible
# 956                          f                     moderate
# 2811                         f                     flexible
# 3953                         f                     moderate
# 5594                         f                     flexible
# 5886                         f                     moderate
# 7403                         f  strict_14_with_grace_period
# 8574                         f                     flexible
# 9366                         f  strict_14_with_grace_period
# 9784                         f  strict_14_with_grace_period
# 9958                         f  strict_14_with_grace_period
# 10057                        f                     flexible
# 11142                        f                     flexible
# 11368                        f                     flexible
#
#       require_guest_profile_picture require_guest_phone_verification  \
# 154                               f                                f
# 956                               f                                f
# 2811                              f                                f
# 3953                              f                                f
# 5594                              f                                f
# 5886                              f                                f
# 7403                              f                                f
# 8574                              f                                f
# 9366                              f                                f
# 9784                              f                                f
# 9958                              f                                f
# 10057                             f                                f
# 11142                             f                                f
# 11368                             f                                f
#
#       calculated_host_listings_count reviews_per_month  price
# 154                                1               NaN   1600
# 956                                1              1.08   1795
# 2811                               1               NaN   1500
# 3953                               1               NaN   1550
# 5594                               1               NaN   1500
# 5886                               1               NaN   1500
# 7403                               1              0.29   1485
# 8574                               1               NaN   1500
# 9366                               1              0.32   1899
# 9784                               1              0.27   1495
# 9958                               1               NaN   1763
# 10057                              1               NaN   1500
# 11142                              1              0.96   1500
# 11368                              1               NaN   1600
#
# [14 rows x 65 columns]

# %%
test[test["square_feet"] > 500 ]
# Out:
#              id                                              name  \
# 140    27604010               New York city entire real 2 bedroom
# 157      715070                SPECTACULAR HOLIDAY RENTAL/VILLAGE
# 250       17298                         Modern Brownstone living3
# 411      259946                  Budget stay, near transportation
# 673      722464  Large Private Room in Clinton Hill Brooklyn Loft
# ...         ...                                               ...
# 15962    810681                 City View From Brooklyn– 2Bd+2Bth
# 16127    371138                   Comfy Brooklyn 2BD, W/ Backyard
# 16243   1582263                 Sunny Brooklyn apt for cat-lover!
# 16732    250537                               The Lenox in Harlem
# 16785    260451                Fort Greene brownstone 1BR- SUBLET
#
#                                                  summary  \
# 140    I'm a California native living in NYC 16 years...
# 157                                                  NaN
# 250                                                  NaN
# 411                                                  NaN
# 673    Large private bedroom in Loft Apartment. Locat...
# ...                                                  ...
# 15962  Great place for traveling families! Cozy livin...
# 16127  A cozy retreat inside of Greenpoint, a true NY...
# 16243                                                NaN
# 16732  Luxury building in Harlem with a 24 hour doorm...
# 16785                                                NaN
#
#                                                    space  \
# 140                                                  NaN
# 157    LOCATION, LOCATION,LOCATION! Beautifully renov...
# 250    BROOKLYN BROWNSTONE TOWNHOUSE 3rd floor This 3...
# 411    A charming and cozy guest suite in an owner oc...
# 673    The room is large and private. Furnished with ...
# ...                                                  ...
# 15962  This is our nice and spacious apartment in Cli...
# 16127  This apartment has two bedrooms with one queen...
# 16243  A sunny and beautiful spacious one-bedroom apa...
# 16732  This beautiful, spacious apartment is just 4 b...
# 16785  Beautiful floor-through apartment in classic b...
#
#                                              description experiences_offered  \
# 140    I'm a California native living in NYC 16 years...                none
# 157    LOCATION, LOCATION,LOCATION! Beautifully renov...                none
# 250    BROOKLYN BROWNSTONE TOWNHOUSE 3rd floor This 3...                none
# 411    A charming and cozy guest suite in an owner oc...                none
# 673    Large private bedroom in Loft Apartment. Locat...                none
# ...                                                  ...                 ...
# 15962  Great place for traveling families! Cozy livin...                none
# 16127  A cozy retreat inside of Greenpoint, a true NY...                none
# 16243  A sunny and beautiful spacious one-bedroom apa...                none
# 16732  Luxury building in Harlem with a 24 hour doorm...                none
# 16785  Beautiful floor-through apartment in classic b...                none
#
#                                    neighborhood_overview  \
# 140                                                  NaN
# 157                                                  NaN
# 250                                                  NaN
# 411    Safe & quiet residential neighborhood, across ...
# 673    The neighborhood boasts an array of restaurant...
# ...                                                  ...
# 15962  Clinton Hill/ Frt. Greene is a historic area, ...
# 16127  Great relaxed neighborhood! Beautiful McGolric...
# 16243                                                NaN
# 16732                                                NaN
# 16785                                                NaN
#
#                                                    notes  \
# 140                                                  NaN
# 157                                                  NaN
# 250                                                  NaN
# 411                                                  NaN
# 673    Keys may be picked up at the Clementine Bakery...
# ...                                                  ...
# 15962  If you are visiting us in Winter we will do ou...
# 16127  We have a dog! He won't be there while you are...
# 16243                                                NaN
# 16732                                                NaN
# 16785                                                NaN
#
#                                                  transit  \
# 140      closest to F train as well as the 4/5/6 trains.
# 157                                                  NaN
# 250                                                  NaN
# 411    To Manhattan: Direct X-buses: X-4,5,7 & 8. 22 ...
# 673    Accessible from the G and C trains. Close and ...
# ...                                                  ...
# 15962  Easy access to Trains (G,A,C,E,Q,R) or Taxi (a...
# 16127  L train 15-20 min walk form our place G train ...
# 16243                                                NaN
# 16732                                                NaN
# 16785                                                NaN
#
#                                                   access  ...  \
# 140                                                  NaN  ...
# 157                                                  NaN  ...
# 250                                                  NaN  ...
# 411                                                  NaN  ...
# 673    Guests have access to a shared rooftop deck ju...  ...
# ...                                                  ...  ...
# 15962  You will have access to all of our amenities, ...  ...
# 16127  Acess Is given to the whole place, except for ...  ...
# 16243                                                NaN  ...
# 16732                       All access to the apartment.  ...
# 16785                                                NaN  ...
#
#       review_scores_communication review_scores_location  review_scores_value  \
# 140                          10.0                   10.0                  9.0
# 157                           NaN                    NaN                  NaN
# 250                           9.0                    8.0                  9.0
# 411                          10.0                   10.0                  9.0
# 673                           NaN                    NaN                  NaN
# ...                           ...                    ...                  ...
# 15962                        10.0                    8.0                  9.0
# 16127                        10.0                   10.0                  9.0
# 16243                        10.0                    9.0                  9.0
# 16732                         NaN                    NaN                  NaN
# 16785                        10.0                   10.0                  9.0
#
#       instant_bookable is_business_travel_ready          cancellation_policy  \
# 140                  f                        f  strict_14_with_grace_period
# 157                  f                        f                     flexible
# 250                  t                        f  strict_14_with_grace_period
# 411                  f                        f  strict_14_with_grace_period
# 673                  f                        f  strict_14_with_grace_period
# ...                ...                      ...                          ...
# 15962                t                        f  strict_14_with_grace_period
# 16127                f                        f                     moderate
# 16243                f                        f                     flexible
# 16732                f                        f                     moderate
# 16785                f                        f  strict_14_with_grace_period
#
#       require_guest_profile_picture require_guest_phone_verification  \
# 140                               t                                t
# 157                               f                                f
# 250                               f                                f
# 411                               f                                f
# 673                               f                                f
# ...                             ...                              ...
# 15962                             f                                f
# 16127                             f                                f
# 16243                             f                                f
# 16732                             f                                f
# 16785                             f                                f
#
#       calculated_host_listings_count  reviews_per_month
# 140                                2               0.87
# 157                                1                NaN
# 250                                3               0.44
# 411                                4               0.09
# 673                                2                NaN
# ...                              ...                ...
# 15962                              1               0.03
# 16127                              1               0.12
# 16243                              1               0.39
# 16732                              2                NaN
# 16785                              2               0.05
#
# [91 rows x 64 columns]

# %%
ring()
