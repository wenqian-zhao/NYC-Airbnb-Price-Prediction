# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("train.csv")
df.head(10)
# Out:
# c:\users\zhaow\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3169: DtypeWarning: Columns (30) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#          id                                               name  \
# 0  22267382           Modern and Cozy Large Studio in Brooklyn
# 1   2473861                   Royal Harlem TRIPLEX Home 5 Beds
# 2  25079703                          Sunny East Village Studio
# 3   9342478                 Beautiful, airy, light-filled room
# 4   4866426                Private Room in Prime Brooklyn Spot
# 5  19115443  26th FLOOR-RIVER VIEWS& MASSIVE SPACE-SUTTON P...
# 6  12132427                     Spacious 1 BR in East Village!
# 7  27551517  Large sunny 1 ROOM in UES, Huge roof balcony &...
# 8  27016367     2 Floor duplex Event space for private party's
# 9  14028380                  Spacious 2 Floor 1 Bed Apartment!
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33538 entries, 0 to 33537
# Data columns (total 65 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                33538 non-null  int64
#  1   name                              33526 non-null  object
#  2   summary                           32266 non-null  object
#  3   space                             23038 non-null  object
#  4   description                       33230 non-null  object
#  5   experiences_offered               33538 non-null  object
#  6   neighborhood_overview             19948 non-null  object
#  7   notes                             13447 non-null  object
#  8   transit                           20796 non-null  object
#  9   access                            19304 non-null  object
#  10  interaction                       18670 non-null  object
# ...

# %%
df.describe()
# Out:
#                  id       host_id  host_acceptance_rate  host_listings_count  \
# count  3.353800e+04  3.353800e+04                   0.0         33533.000000
# mean   1.566316e+07  5.420691e+07                   NaN            10.006799
# std    8.788870e+06  6.149736e+07                   NaN            85.869452
# min    2.515000e+03  2.830000e+02                   NaN             0.000000
# 25%    8.173466e+06  7.130984e+06                   NaN             1.000000
# 50%    1.633786e+07  2.662292e+07                   NaN             1.000000
# 75%    2.276632e+07  8.248502e+07                   NaN             2.000000
# max    2.977318e+07  2.240015e+08                   NaN          2271.000000
#
#        accommodates     bathrooms      bedrooms          beds  square_feet  \
# count  33538.000000  33478.000000  33505.000000  33507.000000   341.000000
# mean       2.856789      1.141376      1.176869      1.571313   738.958944
# ...

# %%
# 初步drop缺失值过多、长段文字、或者host-unique的features
def drop_initial(df): 
    cols = ["name", "summary", "space", "experiences_offered", 
            "access", "host_acceptance_rate", "notes",
            "description", "neighborhood_overview", "interaction",
            "house_rules", "host_id", "host_name", "host_about",
            "host_location", "city", "state", "zipcode", "country",
            "country_code", "host_response_time", "host_neighbourhood",
            "host_has_profile_pic"
           ]
    return df.drop(cols,  axis = 1)
drop_initial(df)
# Out:
#              id                                            transit  \
# 0      22267382                          Subway: 2,3,4,5,A,C,B,Q,G
# 1       2473861  PUBLIC TRANSPORTATION: Conveniently near all p...
# 2      25079703                                                NaN
# 3       9342478                                                NaN
# 4       4866426  Super convenient to almost all subway lines. A...
# ...         ...                                                ...
# 33533   3958032                                                NaN
# 33534   7987209  Apartment is located at 70 W 45th Street (betw...
# 33535    796128                                                NaN
# 33536  17281121  Very Close to subway lines A and 1 trains. Les...
# 33537  17414910  The new Q train line has just opened on 2nd av...
#
#        host_since host_response_rate host_is_superhost  host_listings_count  \
# 0      2012-03-12                NaN                 f                  1.0
# ...

# %%
# 查看host_is_superhost的不同值
print(df["host_is_superhost"].value_counts(dropna=False))
# 查看host_identity_verified的不同值
df["host_is_superhost"].value_counts(dropna=False)
# Out:
# f      28007
# t       5526
# NaN        5
# Name: host_is_superhost, dtype: int64

# %%
# 查看
df[df["country"] == "Uruguay"]
# Out:
#            id                                name  \
# 7576  6645634  New unit in the heart of Manhatten
#
#                                                 summary space  \
# 7576  Brand new one bedroom apartment right on Manha...   NaN
#
#                                             description experiences_offered  \
# 7576  Brand new one bedroom apartment right on Manha...                none
#
#      neighborhood_overview notes transit access  ...  \
# 7576                   NaN   NaN     NaN    NaN  ...
#
#      review_scores_communication review_scores_location  review_scores_value  \
# 7576                         9.0                    9.0                  9.0
#
#      instant_bookable is_business_travel_ready          cancellation_policy  \
# 7576                f                        f  strict_14_with_grace_period
#
#      require_guest_profile_picture require_guest_phone_verification  \
# 7576                             f                                f
#
# ...

# %%
# 查看outliers
df[df["price"]>1000]
# Out:
#              id                                               name  \
# 598    18001363     Fashion & Celeb Photography NOT OVERNIGHT STAY
# 1095    2666204                     Female Summer Sublet Near CUMC
# 2251    8739642  Designer Spacious and Clean Gem in FLATIRON DIST.
# 2263   28356870  Magical home luxury Upper East Side Central Park.
# 2291   19178296   Quiet, Calm and Clean Sanctuary in the Big Apple
# ...         ...                                                ...
# 32847   9793676                    3 Bed Apt - 63rd St and Madison
# 33062  22780195                  Greenwich Street V by ONEFINESTAY
# 33312  25161105       4 br 4 bath luxury designer's loft - midtown
# 33344   4660022                     Best Block Luxury Loft in SoHo
# 33534   7987209                Floor 35th in the heart of New York
#
#                                                  summary  \
# 598    THIS IS NOT AN OVER NIGHT STAY! As a celebrity...
# ...

# %%
# 查看access的缺失值相对应的值
df[df["access"].isnull()]
# Out:
#              id                                               name  \
# 3       9342478                 Beautiful, airy, light-filled room
# 5      19115443  26th FLOOR-RIVER VIEWS& MASSIVE SPACE-SUTTON P...
# 8      27016367     2 Floor duplex Event space for private party's
# 10     20917330                   Beautiful Williamsburg Apartment
# 11     13466663                 Cozy bedroom in downtown Manhattan
# ...         ...                                                ...
# 33523  25185813         Gorgeous WONDERFUL Apt in The Heart of NYC
# 33525  10232344                  Cozy studio in heart of Manhattan
# 33532  21766709  Room at this West Village Gorgeous, Modern 4 Beds
# 33533   3958032                    Private Room Amazing View in EV
# 33535    796128                 Cozy room for rent in duplex house
#
#                                                  summary  \
# 3      Private, spacious, comfortable room in 2-bed f...
# ...

# %%
# 查看property_type
df.groupby("property_type")["price"].aggregate(["mean", "count"]).sort_values(by = "count")
# Out:
#                               mean  count
# property_type
# Timeshare               425.000000      1
# Island                   60.000000      1
# Cabin                   110.000000      1
# Casa particular (Cuba)   60.000000      1
# Chalet                  212.000000      1
# Houseboat               500.000000      1
# Train                    90.000000      1
# Tent                    180.000000      3
# Camper/RV               111.333333      3
# Cottage                 136.666667      3
# Aparthotel              262.400000      5
# Boat                    215.000000      5
# Tiny house               95.444444      9
# Villa                    65.578947     19
# Bungalow                133.947368     19
# Hotel                   358.206897     29
# Hostel                   71.781250     32
# Guesthouse              147.486486     37
# Resort                  418.846154     65
# Boutique hotel          179.382353     68
# Bed and breakfast       111.397059     68
# ...

# %%
# Proper_type transform
def proper_type_trasnform(col):

# %%
cheat = pd.read_csv("test.csv")
cheat.head()
# Out:
#          id                                              name  \
# 0  19307997               Super Lux 2BR in Downtown Manhattan
# 1  20176193       Vintage Eclectic Brownstone Pad in Brooklyn
# 2  19485371                          Spacious Harlem Hideaway
# 3  13079990                  Spacius private room in Brooklyn
# 4  22339757  *Dg) Delightful Private Room 20 min to Manhattan
#
#                                              summary  \
# 0  Prepare to be WOWED! This spectacularly bright...
# 1  Ideal for romantic, creative types, this is an...
# 2  Postive Vibes . This is our Harlem tree house,...
# 3  Newly renovated apartment, its a 3 bedroom apa...
# 4  Hi my home is only 2 blocks from the subway st...
#
#                                                space  \
# 0  Top of the line Wolf and Sub-Zero appliances, ...
# 1  Not your typical New York abode, my apartment ...
# 2  The private room is very spacious and cozy. Th...
# ...

# %%
cheat[cheat["id"] == 2539]
# Out:
#         id                                name  \
# 9669  2539  Clean & quiet apt home by the park
#
#                                        summary  \
# 9669  Renovated apt home in elevator building.
#
#                                                   space  \
# 9669  Spacious, renovated, and clean apt home, one b...
#
#                                             description experiences_offered  \
# 9669  Renovated apt home in elevator building. Spaci...                none
#
#                                 neighborhood_overview  \
# 9669  Close to Prospect Park and Historic Ditmas Park
#
#                                                   notes  \
# 9669  If this room is unavailable on your desired da...
#
#                                                 transit access  ...  \
# 9669  Very close to F and G trains and Express bus i...    NaN  ...
#
#      review_scores_communication review_scores_location  review_scores_value  \
# ...
